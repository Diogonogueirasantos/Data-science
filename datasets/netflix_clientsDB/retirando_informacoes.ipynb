# %%
import pandas as pd 
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('dataset/netflix_user_v1.csv')

# %%
df
# Out:
#        ID_Usuário  Idade       País Assinaturas  Tempo_assistido  \
# 0               1     18     France     Premium            80.26
# 1               2     23        USA     Premium           321.75
# 2               3     60         UK      Basico            35.89
# 3               4     44        USA     Premium           261.56
# 4               5     68        USA      Padrao           909.30
# ...           ...    ...        ...         ...              ...
# 24995       24996     18  Australia     Premium           183.88
# 24996       24997     17        USA     Premium           112.37
# 24997       24998     14        USA     Premium           351.80
# 24998       24999     71        USA      Basico           655.89
# 24999       25000     19    Germany     Premium           207.06
#
#          Genero_favorito Ultimo_Login
# 0                  Drama   2024-05-12
# 1      Ficcao cientifica   2025-02-05
# 2                Comedia   2025-01-24
# ...

# %%
#Verificando a proporção das categorias de genero

drama = len(df.loc[df['Genero_favorito'] == 'Drama'])
ficcao_cientifica = len(df.loc[df['Genero_favorito'] == 'Ficcao cientifica'])
comedia = len(df.loc[df['Genero_favorito'] == 'Comedia'])
horror = len(df.loc[df['Genero_favorito'] == 'Horror'])
acao = len(df.loc[df['Genero_favorito'] == 'Acao'])
documentario = len(df.loc[df['Genero_favorito'] == 'Documentario'])
teste = [7550]

# %%
representacao_categorias = [drama, ficcao_cientifica, comedia, horror, acao, documentario]
rotulos = ["Drama", "Ficcao_Cientifica", "Comedia", "Horror", "Acao", "Documentario"]

# %%
plt.bar(representacao_categorias, rotulos)
plt.show()
