# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/netflix_users.csv')

# %%
df.head(10)
# Out:
#    User_ID             Name  Age Country Subscription_Type  Watch_Time_Hours  \
# 0        1   James Martinez   18  France           Premium             80.26
# 1        2      John Miller   23     USA           Premium            321.75
# 2        3       Emma Davis   60      UK             Basic             35.89
# 3        4      Emma Miller   44     USA           Premium            261.56
# 4        5       Jane Smith   68     USA          Standard            909.30
# 5        6    David Johnson   21     USA          Standard            615.93
# 6        7   John Hernandez   57  Canada          Standard            755.47
# 7        8  Katie Hernandez   68     USA          Standard            145.23
# 8        9   James Williams   39      UK             Basic            950.14
# 9       10       Alex Davis   55  Mexico          Standard            696.66
#
#   Favorite_Genre  Last_Login
# 0          Drama  2024-05-12
# 1         Sci-Fi  2025-02-05
# 2         Comedy  2025-01-24
# ...

# %%
df.tail(10)
# Out:
#        User_ID              Name  Age    Country Subscription_Type  \
# 24990    24991      Chris Miller   52     Brazil             Basic
# 24991    24992    Sarah Williams   43    Germany          Standard
# 24992    24993       James Brown   47      India          Standard
# 24993    24994     Alex Martinez   22     Brazil             Basic
# 24994    24995       Jane Miller   76        USA          Standard
# 24995    24996      David Miller   18  Australia           Premium
# 24996    24997       Jane Miller   17        USA           Premium
# 24997    24998      Sarah Miller   14        USA           Premium
# 24998    24999  Michael Williams   71        USA             Basic
# 24999    25000       James Jones   19    Germany           Premium
#
#        Watch_Time_Hours Favorite_Genre  Last_Login
# 24990            476.63         Horror  2024-05-25
# 24991            361.23         Sci-Fi  2025-01-26
# 24992            411.40    Documentary  2024-03-15
# ...

# %%
#Visualizando a estrutura do dataset
df.shape
# Out:
# (25000, 8)

# %%
#Verificando a possibilidade de valores nulos
df.isnull().sum()
# Out:
# User_ID              0
# Name                 0
# Age                  0
# Country              0
# Subscription_Type    0
# Watch_Time_Hours     0
# Favorite_Genre       0
# Last_Login           0
# dtype: int64

# %%
df.head(10)
# Out:
#    User_ID             Name  Age Country Subscription_Type  Watch_Time_Hours  \
# 0        1   James Martinez   18  France           Premium             80.26
# 1        2      John Miller   23     USA           Premium            321.75
# 2        3       Emma Davis   60      UK             Basic             35.89
# 3        4      Emma Miller   44     USA           Premium            261.56
# 4        5       Jane Smith   68     USA          Standard            909.30
# 5        6    David Johnson   21     USA          Standard            615.93
# 6        7   John Hernandez   57  Canada          Standard            755.47
# 7        8  Katie Hernandez   68     USA          Standard            145.23
# 8        9   James Williams   39      UK             Basic            950.14
# 9       10       Alex Davis   55  Mexico          Standard            696.66
#
#   Favorite_Genre  Last_Login
# 0          Drama  2024-05-12
# 1         Sci-Fi  2025-02-05
# 2         Comedy  2025-01-24
# ...

# %%
#Alterando o nome dos rótulos
df.rename(columns={"User_ID":"ID_Usuário", "Name":"Nome","Country":"País", "Age":"Idade", "Subscription_Type":"Assinaturas",
                   "Watch_Time_Hours":"Tempo_assistido", "Favorite_Genre":"Genero_favorito", "Last_Login":"Ultimo_Login"}, inplace=True)

# %%
df.head(10)
# Out:
#    ID_Usuário             Nome  Idade    País Assinaturas  Tempo_assistido  \
# 0           1   James Martinez     18  France     Premium            80.26
# 1           2      John Miller     23     USA     Premium           321.75
# 2           3       Emma Davis     60      UK       Basic            35.89
# 3           4      Emma Miller     44     USA     Premium           261.56
# 4           5       Jane Smith     68     USA    Standard           909.30
# 5           6    David Johnson     21     USA    Standard           615.93
# 6           7   John Hernandez     57  Canada    Standard           755.47
# 7           8  Katie Hernandez     68     USA    Standard           145.23
# 8           9   James Williams     39      UK       Basic           950.14
# 9          10       Alex Davis     55  Mexico    Standard           696.66
#
#   Genero_favorito Ultimo_Login
# 0           Drama   2024-05-12
# 1          Sci-Fi   2025-02-05
# 2          Comedy   2025-01-24
# ...
