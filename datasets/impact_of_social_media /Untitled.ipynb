# %%
import pandas as pd
import numpy as np
from scipy import stats
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('Social_MediaV2.csv')

# %%
df.head(5)
# Out:
#    ID_Cliente  Idade     Genero  Ganho_Anual (USD)  Renda_Mensal  \
# 0           1     28   Feminino              45000       3750.00
# 1           2     35  Masculino              60000       5000.00
# 2           4     40  Masculino              75000       6250.00
# 3           5     29   Feminino              55000       4583.33
# 4           6     45  Masculino              80000       6666.67
#
#   Nivel_de_educacao  Tempo_de_Uso (Horas/Dias)        Redes_Sociais  \
# 0       Bacharelado                        2.5   Instagram, Twitter
# 1          Mestrado                        1.8  Facebook, Instagram
# 2         Doutorado                        3.2   Facebook, LinkedIn
# 3       Bacharelado                        2.0    Instagram, TikTok
# 4       Bacharelado                        3.5    Twitter, LinkedIn
#
#    Nivel_de_Influencia Decisao_de_Compra Categoria_do_Produto     Produto  \
# 0  Muito Influenciavel               Sim              Fashion       Dress
# ...

# %%
df['Z-score'] = stats.zscore(df['Renda_Mensal'])

# %%
df.head(5)
# Out:
#    ID_Cliente  Idade     Genero  Ganho_Anual (USD)  Renda_Mensal  \
# 0           1     28   Feminino              45000       3750.00
# 1           2     35  Masculino              60000       5000.00
# 2           4     40  Masculino              75000       6250.00
# 3           5     29   Feminino              55000       4583.33
# 4           6     45  Masculino              80000       6666.67
#
#   Nivel_de_educacao  Tempo_de_Uso (Horas/Dias)        Redes_Sociais  \
# 0       Bacharelado                        2.5   Instagram, Twitter
# 1          Mestrado                        1.8  Facebook, Instagram
# 2         Doutorado                        3.2   Facebook, LinkedIn
# 3       Bacharelado                        2.0    Instagram, TikTok
# 4       Bacharelado                        3.5    Twitter, LinkedIn
#
#    Nivel_de_Influencia Decisao_de_Compra Categoria_do_Produto     Produto  \
# 0  Muito Influenciavel               Sim              Fashion       Dress
# ...

# %%
df.loc[(df['Z-score'] > -2) & (df['Z-score'] > 2) ]
# Out:
#     ID_Cliente  Idade     Genero  Ganho_Anual (USD)  Renda_Mensal  \
# 2            4     40  Masculino              75000       6250.00
# 4            6     45  Masculino              80000       6666.67
# 31          33     40  Masculino              78000       6500.00
#
#    Nivel_de_educacao  Tempo_de_Uso (Horas/Dias)       Redes_Sociais  \
# 2          Doutorado                        3.2  Facebook, LinkedIn
# 4        Bacharelado                        3.5   Twitter, LinkedIn
# 31          Mestrado                        2.2   Twitter, LinkedIn
#
#     Nivel_de_Influencia Decisao_de_Compra Categoria_do_Produto    Produto  \
# 2   Muito Influenciavel               Sim                 Food     Burger
# 4   Muito Influenciavel               Sim          Electronics         TV
# 31    Alguma Influencia               Sim              Fitness  Treadmill
#
#     Total_Gasto (USD)         Nome_da_Marca         Cidade   Z-score
# ...

# %%
len(df.loc[df['Genero'] == "Feminino"])
# Out:
# 149

# %%
len(df.loc[df['Genero'] == "Masculino"])
# Out:
# 150

# %%
df.shape
# Out:
# (299, 16)

# %%
df[df['Genero'] == "Masculino"]['Renda_Mensal'].mean().round(2)
# Out:
# 4993.33

# %%
df[df['Genero'] == "Feminino"]['Renda_Mensal'].mean().round(2)
# Out:
# 4261.74

# %%
df['Renda_Mensal'].head(25)
# Out:
# 0     3750.00
# 1     5000.00
# 2     6250.00
# 3     4583.33
# 4     6666.67
# 5     4833.33
# 6     3333.33
# 7     5166.67
# 8     4000.00
# 9     5833.33
# 10    3000.00
# 11    4666.67
# 12    4000.00
# 13    4250.00
# 14    5833.33
# 15    4583.33
# 16    5666.67
# 17    5166.67
# 18    3500.00
# 19    4833.33
# 20    5166.67
# 21    4000.00
# 22    4333.33
# 23    6000.00
# 24    4583.33
# Name: Renda_Mensal, dtype: float64

# %%
len(df.loc[(df['Renda_Mensal'] >= 3000) & (df['Renda_Mensal'] < 4250)])
# Out:
# 71

# %%
len(df.loc[(df['Renda_Mensal'] >= 4250) & (df['Renda_Mensal'] < 4583)])
# Out:
# 76

# %%
len(df.loc[(df['Renda_Mensal'] >= 4583) & (df['Renda_Mensal'] < 5166)])
# Out:
# 65

# %%
len(df.loc[(df['Renda_Mensal'] >= 5166) & (df['Renda_Mensal'] <= 6667)])
# Out:
# 87

# %%
df['Renda_Mensal'].max()
# Out:
# 6666.67

# %%
df['Variancia_Renda'] = df['Renda_Mensal'].var()

# %%
df.head(15)
# Out:
#     ID_Cliente  Idade     Genero  Ganho_Anual (USD)  Renda_Mensal  \
# 0            1     28   Feminino              45000       3750.00
# 1            2     35  Masculino              60000       5000.00
# 2            4     40  Masculino              75000       6250.00
# 3            5     29   Feminino              55000       4583.33
# 4            6     45  Masculino              80000       6666.67
# 5            7     32   Feminino              58000       4833.33
# 6            8     25   Feminino              40000       3333.33
# 7            9     30  Masculino              62000       5166.67
# 8           10     27   Feminino              48000       4000.00
# 9           11     38   Feminino              70000       5833.33
# 10          12     24  Masculino              36000       3000.00
# 11          13     31   Feminino              56000       4666.67
# 12          14     26  Masculino              48000       4000.00
# ...

# %%
df.describe()
# Out:
#        ID_Cliente       Idade  Ganho_Anual (USD)  Renda_Mensal  \
# count  299.000000  299.000000         299.000000    299.000000
# mean   150.993311   29.508361       55545.150502   4628.762040
# std     86.469648    3.275252        8366.628435    697.219052
# min      1.000000   23.000000       36000.000000   3000.000000
# 25%     76.500000   27.000000       51000.000000   4250.000000
# 50%    151.000000   29.000000       55000.000000   4583.330000
# 75%    225.500000   32.000000       62000.000000   5166.670000
# max    300.000000   45.000000       80000.000000   6666.670000
#
#        Tempo_de_Uso (Horas/Dias)  Total_Gasto (USD)       Z-score  \
# count                 299.000000         299.000000  2.990000e+02
# mean                    2.719732         184.347826 -9.505588e-16
# std                     0.435403         261.742341  1.001676e+00
# min                     1.800000           0.000000 -2.340000e+00
# ...

# %%
df['Variancia_Renda'] = df['Variancia_Renda'].round(2)

# %%
df['Desvio Padrao'] =  df['Renda_Mensal'].std()

# %%
df['Desvio Padrao'] =  df['Desvio Padrao'].round(2)

# %%
df
# Out:
#      ID_Cliente  Idade     Genero  Ganho_Anual (USD)  Renda_Mensal  \
# 0             1     28   Feminino              45000       3750.00
# 1             2     35  Masculino              60000       5000.00
# 2             4     40  Masculino              75000       6250.00
# 3             5     29   Feminino              55000       4583.33
# 4             6     45  Masculino              80000       6666.67
# ..          ...    ...        ...                ...           ...
# 294         296     25   Feminino              44000       3666.67
# 295         297     29  Masculino              58000       4833.33
# 296         298     30   Feminino              57000       4750.00
# 297         299     34  Masculino              70000       5833.33
# 298         300     23   Feminino              36000       3000.00
#
#     Nivel_de_educacao  Tempo_de_Uso (Horas/Dias)        Redes_Sociais  \
# 0         Bacharelado                        2.5   Instagram, Twitter
# ...

# %%
df['Renda_Mensal'].describe()
# Out:
# count     299.000000
# mean     4628.762040
# std       697.219052
# min      3000.000000
# 25%      4250.000000
# 50%      4583.330000
# 75%      5166.670000
# max      6666.670000
# Name: Renda_Mensal, dtype: float64
