# %%
import pandas as pd

# %%
df = pd.read_csv('Datasets/clientes.csv')

# %%
pd.set_option('display.width', None)

# %%
df.drop('pais', axis=1, inplace=True)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                          nome             cpf  idade        data  \
# 0     Sr. Vitor Gabriel Silva  640.719.385-01     90  06/12/1933
# 1               Calebe Santos  651.297.384-46     40  06/03/1984
# 2                Evelyn Pires  107.643.528-90     80  09/03/1944
# 3          Maria Julia Castro  164.750.293-43     76  12/04/1947
# 4              Arthur da Rosa  085.167.249-30     53  16/04/1970
# ...                       ...             ...    ...         ...
# 1022              Lívia Nunes  742.380.591-23     49  14/03/1975
# 1023              Joana Silva  349.051.867-57     24  19/09/1999
# 1024              Luigi Porto  826.509.374-83     43  18/08/1980
# 1025          Letícia da Mata  308.742.169-31     47  04/08/1976
# 1026         Dr. Thomas Nunes  967.831.542-46     81  14/08/1942
#
#                                                endereco          estado
# 0     Trevo Emanuel Silva, 482\nVila Tirol\n47847085...        Rondônia
# ...

# %%
df.head()
# Out:
#                       nome             cpf  idade        data  \
# 0  Sr. Vitor Gabriel Silva  640.719.385-01     90  06/12/1933
# 1            Calebe Santos  651.297.384-46     40  06/03/1984
# 2             Evelyn Pires  107.643.528-90     80  09/03/1944
# 3       Maria Julia Castro  164.750.293-43     76  12/04/1947
# 4           Arthur da Rosa  085.167.249-30     53  16/04/1970
#
#                                             endereco          estado
# 0  Trevo Emanuel Silva, 482\nVila Tirol\n47847085...        Rondônia
# 1  Recanto Moraes, 7\nErnesto Nascimento\n96497-6...  Rio de Janeiro
# 2  Travessa de Caldeira, 237\nSanta Terezinha\n84...         Sergipe
# 3  Residencial de Pereira, 20\nJatobá\n62127-165 ...      Pernambuco
# 4  Parque Almeida, 66\nVila Suzana Segunda Seção\...  Santa Catarina

# %%
df.drop(2, axis=0, inplace=True)

# %%
df.isnull().sum()
# Out:
# nome         3
# cpf          7
# idade        0
# data        10
# endereco     5
# estado       5
# dtype: int64

# %%
df.fillna(0)
# Out:
#                          nome             cpf  idade        data  \
# 0     Sr. Vitor Gabriel Silva  640.719.385-01     90  06/12/1933
# 1               Calebe Santos  651.297.384-46     40  06/03/1984
# 3          Maria Julia Castro  164.750.293-43     76  12/04/1947
# 4              Arthur da Rosa  085.167.249-30     53  16/04/1970
# 5                Juan Pereira  520.876.319-21     68  25/10/1955
# ...                       ...             ...    ...         ...
# 1022              Lívia Nunes  742.380.591-23     49  14/03/1975
# 1023              Joana Silva  349.051.867-57     24  19/09/1999
# 1024              Luigi Porto  826.509.374-83     43  18/08/1980
# 1025          Letícia da Mata  308.742.169-31     47  04/08/1976
# 1026         Dr. Thomas Nunes  967.831.542-46     81  14/08/1942
#
#                                                endereco          estado
# 0     Trevo Emanuel Silva, 482\nVila Tirol\n47847085...        Rondônia
# ...

# %%
df.head(500)
# Out:
#                         nome             cpf  idade        data  \
# 0    Sr. Vitor Gabriel Silva  640.719.385-01     90  06/12/1933
# 1              Calebe Santos  651.297.384-46     40  06/03/1984
# 3         Maria Julia Castro  164.750.293-43     76  12/04/1947
# 4             Arthur da Rosa  085.167.249-30     53  16/04/1970
# 5               Juan Pereira  520.876.319-21     68  25/10/1955
# ..                       ...             ...    ...         ...
# 496                Igor Melo  519.307.648-39     97  31/03/1927
# 497    Sra. Vitória Carvalho  528.049.736-38     35  20/02/1989
# 498             Sofia Duarte  412.835.697-28     18  09/07/2005
# 499          Brenda Nogueira  160.294.358-33     56  23/07/1967
# 500            Rafael Fogaça  569.137.028-68     93  04/03/1931
#
#                                               endereco               estado
# 0    Trevo Emanuel Silva, 482\nVila Tirol\n47847085...             Rondônia
# ...

# %%
df['idade'].mean()
# Out:
# 86.80896686159844

# %%
df.shape
# Out:
# (1026, 6)

# %%
Dados_formatados = df[['nome', 'cpf', 'idade', 'data', 'endereco', 'estado']]
Dados_formatados.to_csv('tabela_clientes.csv', index=False)
